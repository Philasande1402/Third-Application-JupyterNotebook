# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (classification_report,accuracy_score,ConfusionMatrixDisplay,confusion_matrix,roc_curve,roc_auc_score)
from sklearn.ensemble import IsolationForest

# %%
#Read the csv file
df = pd.read_csv('titanic.csv')
#Print first 5 line
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print last 5 
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Non null values and data type
display(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
#Display the null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Display the unique values in each column
df.nunique().sort_values()
# Out:
# Survived         2
# Sex              2
# Pclass           3
# Embarked         3
# Parch            7
# SibSp            7
# Age             88
# Cabin          147
# Fare           248
# Ticket         681
# PassengerId    891
# Name           891
# dtype: int64

# %%
print(df["Age"] == np.nan)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
#Cleaning empty data
#Replace an empty data with fillna()
df.fillna({"Age": 100}, inplace=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  100.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  100.0      1
# 2                               Heikkinen, Miss. Laina  female  100.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  100.0      1
# 4                             Allen, Mr. William Henry    male  100.0      0
# ...

# %%
#Check the null values
df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Using the mode to replace empty cell
mode = df["Cabin"].mode()
df.fillna({"Cabin":mode},inplace = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  100.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  100.0      1
# 6                              McCarthy, Mr. Timothy J    male  100.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female  100.0      1
# 11                            Bonnell, Miss. Elizabeth  female  100.0      0
# ...

# %%
#Using madein to replace empty cell
medain = df["Age"].median()
df.fillna({"Age":medain},inplace = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  100.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  100.0      1
# 6                              McCarthy, Mr. Timothy J    male  100.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female  100.0      1
# 11                            Bonnell, Miss. Elizabeth  female  100.0      0
# ...

# %%
#Using the mean to replace empty cell
mean = df["Age"].mean()
df.fillna({"Age":mean},inplace = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  100.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  100.0      1
# 6                              McCarthy, Mr. Timothy J    male  100.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female  100.0      1
# 11                            Bonnell, Miss. Elizabeth  female  100.0      0
# ...

# %%
#Fix the data type format 
df["Cabin"] = df["Cabin"].astype(str)

# %%
#Remove the wrong format
df.dropna(subset = ["Cabin"] , inplace = True)

# %%
#Replace the wrong values
for c in df.index:
    if df.loc[c,"Age"] == 100:
        df.loc[c,"Age"] = 60

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  60.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  60.0      1
# 6                             McCarthy, Mr. Timothy J    male  60.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female  60.0      1
# 11                           Bonnell, Miss. Elizabeth  female  60.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
#Check the duplicate
print(df.duplicated())
# Out:
# 1      False
# 3      False
# 6      False
# 10     False
# 11     False
#        ...
# 871    False
# 872    False
# 879    False
# 887    False
# 889    False
# Length: 202, dtype: bool

# %%
#Drop the duplicate columns
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  60.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  60.0      1
# 6                              McCarthy, Mr. Timothy J    male  60.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female  60.0      1
# 11                            Bonnell, Miss. Elizabeth  female  60.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(15,6))
df.plot()
plt.title("Summary for the csv file (Titanic.csv)")
plt.xlabel("X labels")
plt.ylabel("Y labels")

plt.show()

# %%
#Calculate the range
range = df["Age"].max() - df["Age"].min()
print(range)
# Out:
# 0.0

# %%
# Calculate the IQR
IQR = df["Age"].quantile(0.75) - df["Age"].quantile(0.25)

print(IQR)
# Out:
# 0.0

# %%
#Calculate the Standard deviation
df["Age"].std()
# Out:
# np.float64(0.0)

# %%
df["Age"].var()
# Out:
# np.float64(0.0)

# %%
#Boxplot graph
plt.figure(figsize = (8,6))

plt.boxplot(df["Survived"],orientation = "horizontal")
plt.show()

# %%
#for miss values
missing_values = df.isnull().sum()
missing_table = pd.DataFrame({
    "Missing Value" : missing_values,
    "Missing Percentage" : (missing_values / len(df) * 100).round(3)
})

print(missing_table)
# Out:
#              Missing Value  Missing Percentage
# PassengerId              0                 0.0
# Survived                 0                 0.0
# Pclass                   0                 0.0
# Name                     0                 0.0
# Sex                      0                 0.0
# Age                      0                 0.0
# SibSp                    0                 0.0
# Parch                    0                 0.0
# Ticket                   0                 0.0
# Fare                     0                 0.0
# Cabin                    0                 0.0
# Embarked                 0                 0.0

# %%
#Draw the grapgh for missing values
missing_table = missing_table[missing_table["Missing Value"] >0].sort_values(by = "Missing Value",ascending = False)

missing_table.plot(kind="bar",figsize=(8,6))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 4
#       1 #Draw the grapgh for missing values
#       2 missing_table = missing_table[missing_table["Missing Value"] >0].sort_values(by = "Missing Value",ascending = False)
#       3
# ----> 4 missing_table.plot(kind="bar",figsize=(8,6))
#       5 plt.show()
#
# File ~\venv\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
#Plot the hist grph
plt.figure(figsize = (8,5))

plt.hist(
    df["Age"],
    bins = 30
)
plt.show()

# %%
#Plot the pie chart graph
plt.figure(figsize=(8, 6))

df["Sex"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.show()

# %%
#Plot the scatter plot graph
plt.figure(figsize = (8,7))

plt.scatter(
    df["Age"],
    df["Fare"]
)
plt.show()
